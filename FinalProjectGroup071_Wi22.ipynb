# %% [markdown]
# # COGS 108 - The Effect of COVID-19 on Technology and Travel Stocks

# %% [markdown]
# ## Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [  ] YES - make available
# * [X] NO - keep private

# %% [markdown]
# # Overview

# %% [markdown]
# With the advent of COVID-19 infections around the world in 2020, a sudden stock market crash affected millions in the United States that same year. Our team wants to know if the COVID-19 infection rate had a significant effect on the stock markets since the initial crash for the rest of 2020. Specifically, we want to observe whether stock markets in the U.S. close and open based on the rise and fall of COVID-19 infection rates. Based on our analysis we found….[based on conclusion]

# %% [markdown]
# # Names
#
# - Nathaniel Wong
# - Ethan Tan
# - Judy Liu
# - Clara Pozuelos-Reyes
# - Aidan Truel

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# Was the performance of technology-related sectors as represented by the performance of the QQQ as well as physical entertainment companies as represented by the Las Vegas Sands (LVS) corporation in the stock market directly influenced by the rise and fall of COVID-19 infection rates in the 2020 year?

# %% [markdown]
# <a id='background'></a>
#
# ## Background & Prior Work

# %% [markdown]
# The stock market is comprised of and measured in stock market indexes [[1]](https://www.forbes.com/advisor/investing/stock-market-index/). These indexes allow investors the opportunity to track their investment’s health, and whether a stock is on the rise or downfall. These indexes can be composed of several stock types such as agriculture, technology, real estate, and more. The two popular stock indexes are the Dow Jones Industrial Average (DJIA), and Standard & Poor's 500 Index (S&P 500) [[2]](https://www.investopedia.com/ask/answers/difference-between-dow-jones-industrial-average-and-sp-500/#:~:text=The%20DJIA%20tracks%20the%20stock,the%20stock%20markets%20in%20general.). Each index takes measurements of popular company stocks and reports their averages.
# <br><br>
# For our research, we will be using a stock index known as QQQ to measure technology-related stock prices. The QQQ is a combination of multiple notable technology companies and acts as an overview for general trends in technology. To analyze stock in physical entertainment, we will be observing the Las Vegas Sands Corporation (LVS) stock prices. Las Vegas Sands Corporation is a casino and resort company based in Paradise, Nevada. Finally, we will be comparing both stock datasets to the WHO COVID-19 Global Data Report. This data report provided by the World Health Organization provides a global count of new and cumulative COVID-19 cases. We will only look at COVID-19 data in the United States.
# <br><br>
# COVID-19 is a disease discovered in December 2019, in Wuhan, China [[3]](https://www.cdc.gov/coronavirus/2019-ncov/your-health/about-covid-19/basics-covid-19.html). This highly contagious virus spreads through droplets via the mouth and other manners. Symptoms include fever, cough, headache, body aches, and more [[4]](https://www.cdc.gov/coronavirus/2019-ncov/symptoms-testing/symptoms.html). It is recommended to prevent the spread of the virus to wear medical-grade masks when possible that are well-fitted [[5]](https://www.cdc.gov/coronavirus/2019-ncov/prevent-getting-sick/masks.html). Frequent hand washing and general sanitization of shared and high-touch surfaces are also recommended. Beyond these everyday precautions, the CDC and other government agencies recommend receiving the COVID-19 vaccine (a two-dose system) which lessens the likelihood of death and helps patients manage their symptoms.
# <br><br>
# On the whole, to understand how COVID-19 caused a stock market crash in March 2020 is to understand what led up to this event. As more cases of COVID-19 were reported in the U.S., and several states and businesses were shutting down in early March, stock investors feared the unknown that was COVID-19 [[6]](https://www.thebalance.com/fundamentals-of-the-2020-market-crash-4799950). States such as California began declaring a state of emergency on March 4th, 2020 [[7]](https://calmatters.org/health/coronavirus/2021/03/timeline-california-pandemic-year-key-points/), followed by New York on March 7, 2020 [[8]]( https://www.investopedia.com/historical-timeline-of-covid-19-in-new-york-city-5071986). Finally, former President Trump declared a national state of emergency on March 13, 2020. Before March 13, the Dow Jones Industrial Average (DJIA) had already seen a significant point drop. However, three days after the national emergency declaration, March 16, 2020, saw a record low for the DJIA at a 12.93% point fall [[6]](https://www.thebalance.com/fundamentals-of-the-2020-market-crash-4799950). After this, a recession was triggered for the rest of 2020.
# <br><br>
# According to a prior study, stocks such as technology, healthcare, and others saw the most positive equity value [[9]](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7343658/). On the other end, stocks such as entertainment and real estate saw low returns [[9]](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7343658/). That said, our group would like to observe the stocks of U.S.-based companies to determine if COVID-19 did influence the particular stock markets of technology and entertainment.
# <br><br>
# In all, our intereset in finding a trend between COVID-19 infection rates and stock market changes stems from wanting to predict future stock changes
# <br><br>
# References (include links):
# - 1) https://www.forbes.com/advisor/investing/stock-market-index/
# - 2) https://www.investopedia.com/ask/answers/difference-between-dow-jones-industrial-average-and-sp-500/#:~:text=The%20DJIA%20tracks%20the%20stock,the%20stock%20markets%20in%20general.
# - 3) https://www.cdc.gov/coronavirus/2019-ncov/your-health/about-covid-19/basics-covid-19.html
# - 4) https://www.cdc.gov/coronavirus/2019-ncov/symptoms-testing/symptoms.html
# - 5) https://www.cdc.gov/coronavirus/2019-ncov/prevent-getting-sick/masks.html
# - 6) https://www.thebalance.com/fundamentals-of-the-2020-market-crash-4799950
# - 7) https://calmatters.org/health/coronavirus/2021/03/timeline-california-pandemic-year-key-points/
# - 8) https://www.investopedia.com/historical-timeline-of-covid-19-in-new-york-city-5071986
# - 9) https://www.ncbi.nlm.nih.gov/pmc/articles/PMC7343658/

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We hypothesize a clear relationship between the daily count of COVID-19 infection rates for the year 2020 and stock market changes, specifically to market indices tracking technology and entertainment. We predict that the rise of COVID-19 cases led to falling stock prices for physical entertainment-related companies such as Las Vegas Sands(LVS) as lockdowns forced physical locations to shut down during that year, and an increase in stock prices for technology companies such as the QQQ index as quarantined citizens were inclined to use technology-related products for work and entertainment.

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# - Dataset Name: LVS Historical Data
# - Link to the dataset: https://finance.yahoo.com/quote/QQQ/history?period1=1568592000&period2=1644537600&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true
# - Number of observations: 604
#
# QQQ: This data is information about the open and close of the Invesco QQQ Trust Series 1 Fund which tracks majoor technology stocks. We will be using the information from this stock to track the general sentiment of technology companies in relation to corona virus infections. Note that QQQ does not necessarily stand for anything and is merely the stock ticker name.
#
#
#
# - Dataset Name: LVS Historical Data
# - Link to the dataset: https://finance.yahoo.com/quote/LVS/history?period1=1568592000&period2=1644537600&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true
# - Number of observations: 609
#
# LVS: This data is information about the open and close of Las Vegas Sands company, a major casino entertainment conglomerate. We will be using the information from this data to track the general sentiment about physical entertainment companies in relation to corona virus infections.
#
#
# - Dataset Name: WHO COVID-19 Global Data
# - Link to the dataset: https://data.humdata.org/dataset/coronavirus-covid-19-cases-and-deaths
# - Number of observations: 182727
#
# WHO: This data is information about the Coronavirus COVID-19 daily new and cumulative cases and deaths globally. We will be using the information from this data to track the number of cases of COVID-19 in the United States during the 2020 year.
#
#
# Because we are tracking the relationship between COVID-19 infections and the performance of stocks in technology and physical enteretainment sectors, we will ideally combining the data of covid infection rates along with the QQQ and LVS performance data over time to see if there is a general correlation between rising infection rates with rising technology stock performance, and a general correlation between rising infection rates with decreasing phsyical entertainment stock perforamcne.

# %% [markdown]
# # Setup

# %%
from datetime import datetime
import pandas as pd
import numpy as np
import seaborn as sns
import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
QQQ_df = pd.read_csv('./datasets/QQQ.csv')
LVS_df = pd.read_csv('./datasets/LVS.csv')
WHO_df = pd.read_csv('./datasets/WHO-COVID-19-global-data.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
QQQ_df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-09-16  191.300003  192.080002  191.110001  191.679993  188.889801
# 1  2019-09-17  191.699997  192.600006  191.289993  192.600006  189.796417
# 2  2019-09-18  192.199997  192.600006  190.110001  192.520004  189.717560
# 3  2019-09-19  192.860001  194.039993  192.470001  192.839996  190.032898
# 4  2019-09-20  193.110001  193.309998  190.160004  190.800003  188.022614
#
#      Volume
# 0  20319000
# 1  20953400
# 2  29781300
# 3  26039400
# 4  29086100

# %%
LVS_df.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close   Volume
# 0  2019-09-16  59.049999  59.759998  58.919998  59.639999  57.074806  3266200
# 1  2019-09-17  58.070000  59.160000  57.230000  59.110001  57.307491  5347800
# 2  2019-09-18  58.900002  59.000000  57.700001  58.380001  56.599754  2629000
# 3  2019-09-19  58.599998  58.939999  57.349998  57.580002  55.824150  3807300
# 4  2019-09-20  57.650002  57.869999  56.270000  56.330002  54.612267  4804300

# %%
WHO_df.head()
# Out:
#   Date_reported Country_code      Country WHO_region  New_cases  \
# 0    2020-01-03           AF  Afghanistan       EMRO          0
# 1    2020-01-04           AF  Afghanistan       EMRO          0
# 2    2020-01-05           AF  Afghanistan       EMRO          0
# 3    2020-01-06           AF  Afghanistan       EMRO          0
# 4    2020-01-07           AF  Afghanistan       EMRO          0
#
#    Cumulative_cases  New_deaths  Cumulative_deaths
# 0                 0           0                  0
# 1                 0           0                  0
# 2                 0           0                  0
# 3                 0           0                  0
# 4                 0           0                  0

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# In regards to cleaning up the QQQ and LVS stock data, there was minimal steps we had to undertake because the data we collected from Yahoo Finance provided everything we needed in a concise manner without any extraneous data that had to be cleaned up.

# %% [markdown]
# Checking to see if information is missing in QQQ dataframe.

# %%
QQQ_df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# Checking to see if information is missing in the QQQ dataframe

# %%
LVS_df.isna().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# In regards to cleaning up the WHO Covid-19 data, the data was already cleaned because they were provided by a service that directly affiliates with World Health Organization. Due to our need, we have filtered the dataset so we only look at cases from the US and cases that happened in 2020. Below, we first checked for country by unique name.

# %%
WHO_df['Country'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0         Afghanistan
# 1         Afghanistan
# 2         Afghanistan
# 3         Afghanistan
# 4         Afghanistan
#              ...
# 182722       Zimbabwe
# 182723       Zimbabwe
# 182724       Zimbabwe
# 182725       Zimbabwe
# 182726       Zimbabwe
# Name: Country, Length: 182727, dtype: object>

# %% [markdown]
# Then we created a new Dataframe with just cases regarding the US and then checked to see if any information was missing in the Dataframe.

# %%
us_covid_df = WHO_df[WHO_df['Country'] == 'United States of America']

us_covid_df.isna().sum()
# Out:
# Date_reported        0
# Country_code         0
# Country              0
# WHO_region           0
# New_cases            0
# Cumulative_cases     0
# New_deaths           0
# Cumulative_deaths    0
# dtype: int64

# %% [markdown]
# Change the 'Date_reported' column to actual datetime type data and then recheck that the column types are correct.

# %%
us_covid_df['Date_reported'] = pd.to_datetime(us_covid_df['Date_reported'])

us_covid_df.dtypes
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# Date_reported        datetime64[ns]
# Country_code                 object
# Country                      object
# WHO_region                   object
# New_cases                     int64
# Cumulative_cases              int64
# New_deaths                    int64
# Cumulative_deaths             int64
# dtype: object

# %%
# Checking the column names of the dataframe
us_covid_df.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
# Selecting only the necessary columns needed to do our analysis
us_covid_df = us_covid_df[['Date_reported', 'Country', 'New_cases', 'Cumulative_cases', 
                          'New_deaths', 'Cumulative_deaths']]

# Reconfiguring dataframe to include dates only in the year 2020
us_covid_df.loc[us_covid_df['Date_reported'].dt.year == 2020]
# Out:
#        Date_reported                   Country  New_cases  Cumulative_cases  \
# 174246    2020-01-03  United States of America          0                 0
# 174247    2020-01-04  United States of America          0                 0
# 174248    2020-01-05  United States of America          0                 0
# 174249    2020-01-06  United States of America          0                 0
# 174250    2020-01-07  United States of America          0                 0
# ...              ...                       ...        ...               ...
# 174605    2020-12-27  United States of America     158525          18894000
# 174606    2020-12-28  United States of America     149358          19043358
# 174607    2020-12-29  United States of America     152831          19196189
# 174608    2020-12-30  United States of America     178998          19375187
# 174609    2020-12-31  United States of America     209046          19584233
#
#         New_deaths  Cumulative_deaths
# ...

# %%
# extract a subset of us_covid_df with data from the year of 2020
us_covid_2020_df = us_covid_df.loc[us_covid_df['Date_reported'].dt.year == 2020]

# change column name from Date_reported to Date
us_covid_2020_df = us_covid_2020_df.rename(columns={'Date_reported': 'Date'})
us_covid_2020_df
# Out:
#              Date                   Country  New_cases  Cumulative_cases  \
# 174246 2020-01-03  United States of America          0                 0
# 174247 2020-01-04  United States of America          0                 0
# 174248 2020-01-05  United States of America          0                 0
# 174249 2020-01-06  United States of America          0                 0
# 174250 2020-01-07  United States of America          0                 0
# ...           ...                       ...        ...               ...
# 174605 2020-12-27  United States of America     158525          18894000
# 174606 2020-12-28  United States of America     149358          19043358
# 174607 2020-12-29  United States of America     152831          19196189
# 174608 2020-12-30  United States of America     178998          19375187
# 174609 2020-12-31  United States of America     209046          19584233
#
#         New_deaths  Cumulative_deaths
# 174246           0                  0
# ...

# %%
# extract a subset of QQQ_df with data from the year of 2020
QQQ_df_2020 = QQQ_df[QQQ_df['Date'].str[:4] == '2020']
QQQ_df_2020
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 75   2020-01-02  214.399994  216.160004  213.979996  216.160004  213.905792
# 76   2020-01-03  213.300003  215.470001  213.279999  214.179993  211.946411
# 77   2020-01-06  212.500000  215.589996  212.240005  215.559998  213.312042
# 78   2020-01-07  215.639999  216.139999  214.850006  215.529999  213.282349
# 79   2020-01-08  215.500000  218.139999  215.160004  217.149994  214.885468
# ..          ...         ...         ...         ...         ...         ...
# 323  2020-12-24  308.470001  310.019989  308.390015  309.559998  308.075806
# 324  2020-12-28  312.250000  313.170013  310.359985  312.679993  311.180847
# 325  2020-12-29  314.049988  314.690002  312.029999  312.959991  311.459503
# 326  2020-12-30  314.160004  314.489990  312.329987  312.970001  311.469482
# 327  2020-12-31  312.869995  314.239990  311.760010  313.739990  312.235748
#
#        Volume
# 75   30969400
# 76   27518900
# ...

# %%
# extract a subset of LVS_df with data from the year of 2020
LVS_df_2020 = LVS_df[LVS_df['Date'].str[:4] == '2020']
LVS_df_2020
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 75   2020-01-02  69.879997  70.940002  69.790001  70.800003  69.415199
# 76   2020-01-03  69.620003  70.150002  69.389999  69.720001  68.356323
# 77   2020-01-06  69.180000  70.120003  69.040001  70.089996  68.719086
# 78   2020-01-07  69.550003  70.199997  69.500000  70.160004  68.787720
# 79   2020-01-08  70.000000  71.300003  69.889999  70.800003  69.415199
# ..          ...        ...        ...        ...        ...        ...
# 323  2020-12-24  57.220001  57.490002  56.709999  57.009998  57.009998
# 324  2020-12-28  58.049999  59.049999  57.360001  58.980000  58.980000
# 325  2020-12-29  59.349998  59.630001  58.070000  58.110001  58.110001
# 326  2020-12-30  58.400002  59.389999  58.130001  58.740002  58.740002
# 327  2020-12-31  58.860001  59.900002  58.320000  59.599998  59.599998
#
#       Volume
# 75   5299600
# 76   2822400
# 77   2922500
# 78   2262800
# 79   3455300
# ..       ...
# ...

# %% [markdown]
# # Data Analysis & Results

# %% [markdown]
# Now, we want to perform an exploratory analysis COVID-19 cases and stock data, vidualizing them in an attempt to find a correlation bewteen the two datas. We begin with the COVID-19 data, using a line graph to demonstrate the change over time.

# %%
# line plot that observes new cases change with time (date reported)
sns.lineplot(x="Date", y="New_cases", data=us_covid_2020_df).set(title="COVID-19 New Cases Throughout 2020")
# Out:
# [Text(0.5, 1.0, 'COVID-19 New Cases Throughout 2020')]

# %% [markdown]
# From the lineplot above, we can observe that new cases comes in waves. There is a downward trend from April to June 2020, and another one from August to October 2020. There is an upward trend in late March and from June to August 2020. There is also an upward spike from October to end of the year.

# %% [markdown]
# Noticing the variation, we also want to check out the number of cumulative cases to see a smoother visualization of overall counts, again using a line plot to see the change over time.

# %%
# line plot that observes cumulative cases with time (date reported)
sns.lineplot(x="Date", y="Cumulative_cases", data=us_covid_2020_df).set(title="Cumulative COVID-19 Cases Throughout 2020")
# Out:
# [Text(0.5, 1.0, 'Cumulative COVID-19 Cases Throughout 2020')]

# %% [markdown]
# From the lineplot above, we can see a steep increase in cumulative cases.

# %%
# add a new column that stores the day-to-day change in new cases
us_covid_2020_df["New_cases_change"] = us_covid_2020_df['New_cases'] - us_covid_2020_df['New_cases'].shift(-1)

# %%
# boxplot for the change in new cases to observe outliers
sns.boxplot(x="New_cases_change", data=us_covid_2020_df).set(title="Change in New Cases Box Plot")
# Out:
# [Text(0.5, 1.0, 'Change in New Cases Box Plot')]

# %% [markdown]
# Now, we want to explore our stock data. We visualize using a line plot in order to see the change over time for these stocks.

# %%
# set our plot size
sns.set(rc= {'figure.figsize':(15,8)})

# %%
ax = sns.lineplot(x='Date', y='Close', data=LVS_df_2020)
x_ticks = ax.set_xticks([i*30 for i in range(10)])
ax.set(title="LVS Performance In 2020")
# Out:
# [Text(0.5, 1.0, 'LVS Performance In 2020')]

# %%
ax = sns.lineplot(x='Date', y='Close', data=QQQ_df_2020)
x_ticks = ax.set_xticks([i*30 for i in range(10)])
ax.set(title="QQQ Performance In 2020")
# Out:
# [Text(0.5, 1.0, 'QQQ Performance In 2020')]

# %% [markdown]
# From the line plots above, we notice that around mid-February, both stock indices take a dip, with LVS dropping much more steeply than QQQ. After this, LVS seems to oscillate a bit before starting a slow rise, whereas QQQ immediately starts to see a steady increase in closing price.

# %% [markdown]
# ## Combined Stock Data
# What we are going to do is create a line graph of QQQ and LVS performance in the 2020 year. We chose to represent the performance of these companies in a line graph because we thought they would be appropriate to display the change over time of the stocks and line graphs are best for representing changes over time.

# %%
fig, ax = plt.subplots()
sns.lineplot(x='Date', y='Close', data=QQQ_df_2020).set(title="Combined Stock Performance of LVS and QQQ in 2020 Side-by-side")
plt.ylabel('Close QQQ (Blue Line)', size=15)
ax2 = ax.twinx()
sns.lineplot(x='Date', y='Close', data=LVS_df_2020, color='r')
plt.ylabel('Close LVS (Red Line)', size=15)
plt.xlabel('Date', size=15)
x_ticks = ax.set_xticks([i*30 for i in range(10)])

# %% [markdown]
# In this plot, as we can see in the initial data, with the onset of COVID, there is a harsh drop in stock price of both QQQ and LVS data. This is to be expected as with worldwide fears over the pandemic, there is no company which is left untouched as the public pulls their money out of companies.
#
# After June of 2020 however, we see that there is a marked change in sentiment in which after the large initial drop, investors start pulling their money back into the market at a slow rate.
# We see that technology has a remarkably stronger performance in that area in comparison to LVS, the Las Vegas Sands stock we are using as a marker for "travel" stocks.
# We reason that this is because technology requires little social contact in order to be useful, whilst physical travel companies require individuals to be in actual locations which was restricted due to government lockdowns and quarantine states around the globe.

# %% [markdown]
# ### Revised graph

# %% [markdown]
# We considered the possibility of being influenced by trends outide of COVID in our stock data by looking at such a big overall change, so we want no now take a more granular look at the closing prices of our stocks. We now analyze the *change* in closing price from the previous day in and perform an analysis on this to create a more focused look on these stocks.

# %%
# generate QQQ data in the form of date, change since previous day
QQQ_data = []
for i in range(1,len(QQQ_df_2020)):
    QQQ_data.append([QQQ_df_2020['Date'].iloc[i],QQQ_df_2020['Close'].iloc[i]-QQQ_df_2020['Close'].iloc[i-1]])
QQQ_data = pd.DataFrame(QQQ_data, columns = ['Date', 'Closing_Change'])

# %%
ax = sns.lineplot(x='Date', y='Closing_Change', data=QQQ_data)
x_ticks = ax.set_xticks([i*30 for i in range(10)])
ax.set(title="QQQ Closing Change Performance In 2020")
# Out:
# [Text(0.5, 1.0, 'QQQ Closing Change Performance In 2020')]

# %%
# generate data in the form of date, change since previous day
LVS_data = []
for i in range(1,len(LVS_df_2020)):
    LVS_data.append([LVS_df_2020['Date'].iloc[i],LVS_df_2020['Close'].iloc[i-1]-LVS_df_2020['Close'].iloc[i]])
LVS_data = pd.DataFrame(LVS_data, columns = ['Date', 'Closing_Change'])

# %%
ax = sns.lineplot(x='Date', y='Closing_Change', data=LVS_data, color='red')
x_ticks = ax.set_xticks([i*30 for i in range(10)])
ax.set(title="LVS Closing Change Performance In 2020")
# Out:
# [Text(0.5, 1.0, 'LVS Closing Change Performance In 2020')]

# %% [markdown]
# Our motivation to look at the combined closing change of LVS and QQQ was to see if there was any significant difference in terms of the measures of central tendency for their changing price between days. In this manner, our team could analyze the relative performance of one stock to another by looking at how positive or negative the average change in price was day to day.

# %%
fig, ax = plt.subplots()
sns.lineplot(x='Date', y='Closing_Change', data=QQQ_data)
plt.ylabel('Closing Change QQQ', size=15)
ax2 = ax.twinx()
sns.lineplot(x='Date', y='Closing_Change', data=LVS_data, color='r')
plt.ylabel('Closing Change LVS', size=15)
plt.xlabel('Date', size=15)
x_ticks = ax.set_xticks([i*30 for i in range(10)])
ax.set(title="Combined Closing Change Performance In 2020")
# Out:
# [Text(0.5, 1.0, 'Combined Closing Change Performance In 2020')]

# %%
# Compare number of positive deltas to negative deltas for QQQ dataset
QQQ_pos_deltas = sum(QQQ_data['Closing_Change'] > 0)
QQQ_neg_deltas = sum(QQQ_data['Closing_Change'] < 0)
QQQ_pos_neg_ratio = QQQ_pos_deltas / QQQ_neg_deltas
print('Ratio of QQQ positive deltas to negative deltas for QQQ dataset:', QQQ_pos_neg_ratio)
# Out:
# Ratio of QQQ positive deltas to negative deltas for QQQ dataset: 1.6526315789473685

# %%
# Compare number of positive deltas to negative deltas for LVS dataset
LVS_pos_deltas = sum(LVS_data['Closing_Change'] > 0)
LVS_neg_deltas = sum(LVS_data['Closing_Change'] < 0)
LVS_pos_neg_ratio = LVS_pos_deltas / LVS_neg_deltas
print('Ratio of positive deltas to negative deltas for LVS dataset:', LVS_pos_neg_ratio)
# Out:
# Ratio of positive deltas to negative deltas for LVS dataset: 1.0916666666666666

# %%
# Compare means of positive delta means to negative delta means for QQQ dataset
QQQ_pos_mean = abs(QQQ_data[QQQ_data['Closing_Change'] > 0]['Closing_Change'].mean())
QQQ_neg_mean = abs(QQQ_data[QQQ_data['Closing_Change'] < 0]['Closing_Change'].mean())
QQQ_pos_neg_mean_ratio = QQQ_pos_mean / QQQ_neg_mean
print('Ratio of QQQ positive changes in value to negative changes', QQQ_pos_neg_mean_ratio)
# Out:
# Ratio of QQQ positive changes in value to negative changes 0.7542071552312263

# %%
# Compare means of positive delta means to negative delta means for LVS dataset
LVS_pos_mean = abs(LVS_data[LVS_data['Closing_Change'] > 0]['Closing_Change'].mean())
LVS_neg_mean = abs(LVS_data[LVS_data['Closing_Change'] < 0]['Closing_Change'].mean())
LVS_pos_neg_mean_ratio = LVS_pos_mean / LVS_neg_mean
print('Ratio of LVS positive changes in value to negative changes', LVS_pos_neg_mean_ratio)
# Out:
# Ratio of LVS positive changes in value to negative changes 0.978999590945929

# %% [markdown]
# In order to analyze the revised stock data, what we decided to do is use the change in values from the closing price of the current day to the day before. In this manner, what we would end up with is the “strength” of the stock by seeing how it changed from day to day. By taking the ratio of positive to negative days, as well as the mean of the positive days and mean of negative days of each respective stock (QQQ and LVS), what we hope to do is determine which of the two was stronger in the sense of having more positive change days, or having larger “positive” days or lesser “negative” days to denote stock strength. From our findings, what we found was that the QQQ had more positive days compared to negative days in comparison to LVS. Moreover, the ratio of positive changes in value to negative changes was much bigger compared to that of LVS’s ratio of positive changes in value to negative changes. This is  in line with our hypothesis as it demonstrates how the QQQ for the most part increased at a larger rate from day to day in comparison to LVS, especially since it has a larger ratio of positive days to negative days. Particular confounding variables which could particularly interfere with these results is the stretch of data we are using to analyze. The data covers the time period of before the COVID crash.

# %% [markdown]
# ### Consideration of Outliers
# Are there any outliers? No.
#
# The data we are performing an analysis on is based on aggregate data of a stock market. Outliers on an individual level may perhaps represent a company closing down or a sudden brief rise in price, but on the scale at which we consider, these individually-scaled outliers do not significantly impact the aggregate market, and neither do we have the data to account for this level of specificity. Each data point in our dataset represents a significant statistic that *should* be included, with the exclusion of any detracting from the overall fidelity of our analysis. Thus, we have determined that we do not have any outliers for the QQQ and LVS datasets.

# %% [markdown]
# ## Merging Datasets

# %%
# change from string to datetime object for QQQ set for merging datasets
QQQ_data['Date'] = pd.to_datetime(QQQ_data['Date'])
QQQ_df_2020['Date'] = pd.to_datetime(QQQ_df_2020['Date'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# change from string to datetime object for LVS set for merging datasets
LVS_data['Date'] = pd.to_datetime(LVS_data['Date'])
LVS_df_2020['Date'] = pd.to_datetime(LVS_df_2020['Date'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# combining covid and stock price data together into a new dataframe
QQQ_covid_df_2020 = us_covid_2020_df.merge(QQQ_df_2020, on="Date")
LVS_covid_df_2020 = us_covid_2020_df.merge(LVS_df_2020, on="Date")

# %%
# combining covid and stock price data together into a new dataframe
QQQ_covid_df_2020_delta = us_covid_2020_df.merge(QQQ_data, on="Date")
LVS_covid_df_2020_delta = us_covid_2020_df.merge(LVS_data, on="Date")

# %%
# plotting relationship between new covid cases and stock closing price
ax = sns.scatterplot(x="New_cases", y="Close", data=QQQ_covid_df_2020)
#sns.scatterplot(x="New_cases", y="Close", data=QQQ_covid_df_2020[QQQ_covid_df_2020['New_cases'] > 100])
ax.set(title="New COVID cases vs QQQ Stock Closing Price")
# Out:
# [Text(0.5, 1.0, 'New COVID cases vs QQQ Stock Closing Price')]

# %%
# plotting relationship between new covid cases and stock closing price
ax = sns.scatterplot(x="New_cases", y="Close", data=LVS_covid_df_2020)
#sns.scatterplot(x="New_cases", y="Close", data=LVS_covid_df_2020[LVS_covid_df_2020['New_cases'] > 100])
ax.set(title="New COVID cases vs LVS Stock Closing Price")
# Out:
# [Text(0.5, 1.0, 'New COVID cases vs LVS Stock Closing Price')]

# %% [markdown]
# From the graphs above we observe what seems to be a clear correlation between new COVID-19 cases and stock closing prices in 2020. There appears a positive correlation between those two variables: as there are more new covid cases, the stock closing price also increase. However, there could be autocorrelation issues here or a tendency for them both to increase. To determine whether a relationship actually exists, we will now look at day to changes in covid cases vs. stock closing prices.

# %%
# plotting relationship between change in covid cases and change in QQQ stock closing price
ax = sns.regplot(x="New_cases_change", y="Closing_Change", data=QQQ_covid_df_2020_delta)
ax.set(title="Change in COVID cases vs change in QQQ Stock Closing Price")
# Out:
# [Text(0.5, 1.0, 'Change in COVID cases vs change in QQQ Stock Closing Price')]

# %% [markdown]
# Here, there seems to be less of a correlation, but we can still observe an increase in slope when we plot a regression line, indicating that there may be a relationship. We will have to run a statistical test to find out.

# %%
# plotting relationship between change in covid cases and change in LVS stock closing price
ax = sns.regplot(x="New_cases_change", y="Closing_Change", data=LVS_covid_df_2020_delta)
ax.set(title="Change in COVID cases vs change in LVS Stock Closing Price")
# Out:
# [Text(0.5, 1.0, 'Change in COVID cases vs change in LVS Stock Closing Price')]

# %% [markdown]
# Again, the correlation is less glaring, however the regression line seems to be steeper here, giving us hope that there may be a relationship. To find out, we run a linear regression and view the results.

# %%
dependent, predictors = patsy.dmatrices('Closing_Change~New_cases_change', QQQ_covid_df_2020_delta)
model = sm.OLS(dependent, predictors)
res_1 = model.fit()

# %%
print(res_1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Closing_Change   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.6031
# Date:                Mon, 14 Mar 2022   Prob (F-statistic):              0.438
# Time:                        00:05:26   Log-Likelihood:                -494.62
# No. Observations:                 176   AIC:                             993.2
# Df Residuals:                     174   BIC:                             999.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept            0.6136      0.307      1.997      0.047       0.007       1.220
# ...

# %%
dependent, predictors = patsy.dmatrices('Closing_Change~New_cases_change', LVS_covid_df_2020_delta)
model = sm.OLS(dependent, predictors)
res_2 = model.fit()

# %%
print(res_2.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:         Closing_Change   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                  0.003
# Method:                 Least Squares   F-statistic:                     1.484
# Date:                Mon, 14 Mar 2022   Prob (F-statistic):              0.225
# Time:                        00:21:44   Log-Likelihood:                -318.17
# No. Observations:                 176   AIC:                             640.3
# Df Residuals:                     174   BIC:                             646.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# Intercept           -0.0885      0.113     -0.785      0.434      -0.311       0.134
# ...

# %% [markdown]
# In both cases, the R-squared value is very low, indicating that only a small percent of the variation in stock closing change is explained by the change in daily covid case counts. Also, the p-value is extremely high (almost 0.5 in both cases) so a relationship is unlikely.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# *   potential biases: information of covid infection numbers may be more accurate in countries with more developed systems of data collection (how to address?)
# *   personally identifiable information: the data sources we've seen so far have already removed PII, but we will be sure to limit PII exposure if any of our data is at risk
# *   data security: how will data be secured?
# *   honest representation: we will strive to make our visualizations, summary statistics, and reports accurately and honestly represent the underlying data
# *   Auditability: the process of generating the analysis will be well-documented and reproducible
# *   Roll back: we will keep track of our model in production through version control using git
# *   Concept drift: we will test and monitor for concept drift to ensure the model remains fair over time
#
# > For our analysis, privacy will not be a major concern as we are not collecting data from individuals or even individual corporations but rather aggregated data such as index funds. To a certain extent, it is inevitable (due to the nature of monopoly capitalism) that the identity of corporations can be inferred since we will break down data by sectors, however this is not a major concern since corporations make their data publicly available for scrutiny by anyone. Furthermore, we will not use personally identifiable information for Covid infections because we care more about total case counts. All our data will be taken from publicly available datasets. For this reason, we will not worry about securing our data.
# > Another ethical concern is honesty and clarity. We will strive to represent data as accurately as possible through data visualizations and statistics. If we have to remove data for our analyses, we will clearly communicate why we had to do so and check that the missing data is random. We will, at every step of the way, ask what biases may exist in the data and our interpretation of the data and take proactive measures to combat dishonest representation. Additionally, we will keep records as our model progresses through version control with Git. Finally, we will be as detailed as possible in the descriptions of our data analysis so that anybody with the same data could reproduce our results.

# %% [markdown]
# # Conclusion & Discussion

# %% [markdown]
# Our project examines the performance of stocks in response to COVID-19, particularly that of technology and physical travel of which we chose the two tickers QQQ and LVS respectively. In understanding how a worldwide pandemic could affect regions in the stock market, individuals could potentially make smarter financial decisions in the future about where to put their money in and when to take their money out of the markets (if a worldwide pandemic ever happens to occur again). We hypothesized that technology stocks would perform much better in relation to travel stocks, using data from Yahoo Finance and the WHO to help create our visualizations.
#
# After looking into visualizations of the data and trying multiple analysis methods, we found that COVID-19 did indeed have a direct positive and negative correlation with QQQ and LVS stock performance respectively. Looking at our visualizations, it is easy to see how QQQ vastly out performs the LVS stock after the month of June 2020, in which we see a sharp rise in the price of the stock while LVS seems to stagnate, ranging around the same stock value for the rest of the 2020 year. Additional analysis into the measures of central tendency for the change in closing prices day to day between LVS and QQQ furthermore go to show how QQQ seemed to have a higher average positive change in comparison to LVS.
#
# This analysis into COVID-19 effects on the stock market is not extremely surprising, but still interesting nonetheless. Sometimes it feels as if the economy is intricately connected with not just the state of society in terms of health, but also its psychological state. In a sense, fear is something which accompanies the market extremely closely not just in terms of the rippling effects of events on the economy, but also the confidence an individual has in keeping money invested and outside his or her own bank account. In this sense, it is thus unsurprising about the continued lack of confidence in physical travel stocks such as LVS, as well as the increased confidence in the performance of technology stocks such as QQQ as a result of COVID-19 government policies, fears, and public responses.

# %% [markdown]
# # Team Contributions

# %% [markdown]
# * Ethan Tan - Data collection & analysis
# * Judy Liu - Data collection & analysis
# * Nathaniel Wong - Data cleaning & Analysis
# * Clara Pozuelos-Reyes - Overview, Background and Prior Work, Data cleaning
# * Aidan Truel - writing ethics and privacy section, Covid-19 EDA, quality control for plotting and outlier analysis, and final regression / analysis of results
